# %%
import h5py
import tables
from pandas import Series, DataFrame
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
filename    = '/home/axel/PycharmProjects/pax/Kr83m_tpc_gaseous_lutz_150522_coin1_th300_6.hdf5'

# %%
pulses = pd.read_hdf(filename,"Pulse")
hits = pd.read_hdf(filename, "Hit")
# works fine

# %%
Peaks = pd.read_hdf(filename2, "Peak") # does not work for some reason
Events = pd.read_hdf(filename2, "Event")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-0ff1885e9606> in <module>()
# ----> 1 Peaks = pd.read_hdf(filename2, "Peak") # does not work for some reason
#       2 Events = pd.read_hdf(filename2, "Event")
#
# /home/axel/anaconda3/lib/python3.4/site-packages/pandas/io/pytables.py in read_hdf(path_or_buf, key, **kwargs)
#     330
#     331     try:
# --> 332         return store.select(key, auto_close=auto_close, **kwargs)
#     333     except:
#     334         # if there is an error, close the store
#
# /home/axel/anaconda3/lib/python3.4/site-packages/pandas/io/pytables.py in select(self, key, where, start, stop, columns, iterator, chunksize, auto_close, **kwargs)
#     672                            auto_close=auto_close)
#     673
# --> 674         return it.get_result()
#     675
#     676     def select_as_coordinates(
#
# /home/axel/anaconda3/lib/python3.4/site-packages/pandas/io/pytables.py in get_result(self, coordinates)
#    1366
#    1367         # directly return the result
# -> 1368         results = self.func(self.start, self.stop, where)
#    1369         self.close()
#    1370         return results
#
# /home/axel/anaconda3/lib/python3.4/site-packages/pandas/io/pytables.py in func(_start, _stop, _where)
#     665             return s.read(start=_start, stop=_stop,
#     666                           where=_where,
# --> 667                           columns=columns, **kwargs)
#     668
#     669         # create the iterator
#
# /home/axel/anaconda3/lib/python3.4/site-packages/pandas/io/pytables.py in read(self, where, columns, **kwargs)
#    4038                 values = values.reshape((1, values.shape[0]))
#    4039
# -> 4040             block = make_block(values, placement=np.arange(len(cols_)))
#    4041             mgr = BlockManager([block], [cols_, index_])
#    4042             frames.append(DataFrame(mgr))
#
# /home/axel/anaconda3/lib/python3.4/site-packages/pandas/core/internals.py in make_block(values, placement, klass, ndim, dtype, fastpath)
#    2099
#    2100     return klass(values, ndim=ndim, fastpath=fastpath,
# -> 2101                  placement=placement)
#    2102
#    2103
#
# /home/axel/anaconda3/lib/python3.4/site-packages/pandas/core/internals.py in __init__(self, values, placement, ndim, fastpath)
#      75             raise ValueError('Wrong number of items passed %d,'
#      76                              ' placement implies %d' % (
# ---> 77                                  len(self.values), len(self.mgr_locs)))
#      78
#      79     @property
#
# ValueError: Wrong number of items passed 243, placement implies 1

# %%
f = h5py.File(filename)   # from main analysis classification
peaks = f.get("Peak")[:]
events = f.get("Event")[:]
pulses = f.get("Pulse")[:]
hits = f.get("Hit")[:]
f.close()

# %%
DataFrame(peaks)    # does not work
DataFrame(events)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-16-3320282c9420> in <module>()
# ----> 1 DataFrame(peaks)    # does not work
#       2 DataFrame(events)
#
# /home/axel/anaconda3/lib/python3.4/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     237                 if columns is None:
#     238                     columns = data_columns
# --> 239                 mgr = self._init_dict(data, index, columns, dtype=dtype)
#     240             elif getattr(data, 'name', None):
#     241                 mgr = self._init_dict({data.name: data}, index, columns,
#
# /home/axel/anaconda3/lib/python3.4/site-packages/pandas/core/frame.py in _init_dict(self, data, index, columns, dtype)
#     339
#     340         return _arrays_to_mgr(arrays, data_names, index, columns,
# --> 341                               dtype=dtype)
#     342
#     343     def _init_ndarray(self, values, index, columns, dtype=None,
#
# /home/axel/anaconda3/lib/python3.4/site-packages/pandas/core/frame.py in _arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#    4801
#    4802     # don't force copy because getting jammed in an ndarray anyway
# -> 4803     arrays = _homogenize(arrays, index, dtype)
#    4804
#    4805     # from BlockManager perspective
#
# /home/axel/anaconda3/lib/python3.4/site-packages/pandas/core/frame.py in _homogenize(data, index, dtype)
#    5110                 v = lib.fast_multiget(v, oindex.values, default=NA)
#    5111             v = _sanitize_array(v, index, dtype=dtype, copy=False,
# -> 5112                                 raise_cast_failure=False)
#    5113
#    5114         homogenized.append(v)
#
# /home/axel/anaconda3/lib/python3.4/site-packages/pandas/core/series.py in _sanitize_array(data, index, dtype, copy, raise_cast_failure)
#    2718     elif subarr.ndim > 1:
#    2719         if isinstance(data, np.ndarray):
# -> 2720             raise Exception('Data must be 1-dimensional')
#    2721         else:
#    2722             subarr = _asarray_tuplesafe(data, dtype=dtype)
#
# Exception: Data must be 1-dimensional

# %%